# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from visualize import report_const_experiment, report_experiment, plot_two_perf_dist, plot_perf_dist

# %matplotlib inline

# %%
report_const_experiment("baseline_tcl_40/p_ref=2.3/", fig_size=(12, 28))

# %%
report_experiment("dqn_2_tcl_40/14/");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.46555 0.4991  0.4618  0.5014  0.5095 ] s
# Mean time per simulation step: 0.487 s, std: 0.0198 s
# Total execution time: 48747.000 s for 100000 steps -> 0.487 s per step
#
# Median performance (MSE) in exploitation mode 0.0085
#
# Average MSE in exploitation mode 0.0100 +- 0.0045
# Average exploitation performance of each agent:
# [0.007264 0.009516 0.007264 0.016524 0.009516]

# %%
plot_two_perf_dist("baseline_tcl_40/p_ref=2.3/k=7", "dqn_2_tcl_40/14/")
