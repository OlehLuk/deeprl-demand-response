# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from visualize import report_const_experiment, report_experiment, plot_two_perf_dist, plot_perf_dist

# %matplotlib inline

# %% [markdown]
# ## Baseline

# %%
report_const_experiment("baseline/p_ref=1.2/", fig_size=(12, 28))

# %% [markdown]
# # DQN 1

# %%
report_experiment("dqn_1/1/");
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.11645 0.11715 0.1154  0.11605 0.1181 ] s
# Mean time per simulation step: 0.117 s, std: 0.0009 s
# Total execution time: 11663.000 s for 100000 steps -> 0.117 s per step
#
# Median performance (MSE) in exploitation mode 0.0145
#
# Average MSE in exploitation mode 0.0161 +- 0.0057
# Average exploitation performance of each agent:
# [0.015419 0.016963 0.016095 0.016158 0.015731]

# %%
report_experiment("dqn_1/2/");
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.1163  0.11655 0.1156  0.11595 0.11555] s
# Mean time per simulation step: 0.116 s, std: 0.0004 s
# Total execution time: 11599.000 s for 100000 steps -> 0.116 s per step
#
# Median performance (MSE) in exploitation mode 0.0159
#
# Average MSE in exploitation mode 0.0189 +- 0.0061
# Average exploitation performance of each agent:
# [0.030681 0.016319 0.015919 0.016089 0.015493]

# %%
report_experiment("dqn_1/3/");
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.10405 0.10725 0.10835 0.1083  0.10845] s
# Mean time per simulation step: 0.107 s, std: 0.0017 s
# Total execution time: 10728.000 s for 100000 steps -> 0.107 s per step
#
# Median performance (MSE) in exploitation mode 0.0145
#
# Average MSE in exploitation mode 0.0162 +- 0.0059
# Average exploitation performance of each agent:
# [0.015501 0.017563 0.015698 0.015973 0.016043]

# %%
report_experiment("dqn_1/4/");
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.10855 0.10835 0.1079  0.109   0.10715] s
# Mean time per simulation step: 0.108 s, std: 0.0006 s
# Total execution time: 10819.000 s for 100000 steps -> 0.108 s per step
#
# Median performance (MSE) in exploitation mode 0.0155
#
# Average MSE in exploitation mode 0.0170 +- 0.0059
# Average exploitation performance of each agent:
# [0.015715 0.018553 0.015338 0.019939 0.015556]

# %%
plot_two_perf_dist("baseline/p_ref=1.2/k=7", "dqn_1/4/")

# %%
report_experiment("dqn_1/5/", n_exp=3);
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.2271  0.23045 0.2319 ] s
# Mean time per simulation step: 0.230 s, std: 0.0020 s
# Total execution time: 13789.000 s for 100000 steps -> 0.138 s per step
#
# Median performance (MSE) in exploitation mode 0.0143
#
# Average MSE in exploitation mode 0.0159 +- 0.0059
# Average exploitation performance of each agent:
# [0.0159   0.015729 0.015953]

# %%
plot_two_perf_dist("baseline/p_ref=1.2/k=7", "dqn_1/5/")

# %%
report_experiment("dqn_1/6/", n_exp=3);
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.22275 0.22655 0.2297 ] s
# Mean time per simulation step: 0.226 s, std: 0.0028 s
# Total execution time: 13580.000 s for 100000 steps -> 0.136 s per step
#
# Median performance (MSE) in exploitation mode 0.0176
#
# Average MSE in exploitation mode 0.0187 +- 0.0060
# Average exploitation performance of each agent:
# [0.022156 0.015626 0.018217]

# %%
report_experiment("dqn_1/7/", n_exp=5);
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.10685 0.1104  0.11155 0.11135 0.11155] s
# Mean time per simulation step: 0.110 s, std: 0.0018 s
# Total execution time: 11034.000 s for 100000 steps -> 0.110 s per step
#
# Median performance (MSE) in exploitation mode 0.0163
#
# Average MSE in exploitation mode 0.0218 +- 0.0070
# Average exploitation performance of each agent:
# [0.044591 0.015425 0.015393 0.01803  0.015489]

# %%
plot_perf_dist("baseline/p_ref=1.2/k=7", ["dqn_1/1/", "dqn_1/7/"], labels=["DDQN", "DQN"])

# %%
report_experiment("dqn_1/6/", n_exp=3);
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.22275 0.22655 0.2297 ] s
# Mean time per simulation step: 0.226 s, std: 0.0028 s
# Total execution time: 13580.000 s for 100000 steps -> 0.136 s per step
#
# Median performance (MSE) in exploitation mode 0.0176
#
# Average MSE in exploitation mode 0.0187 +- 0.0060
# Average exploitation performance of each agent:
# [0.022156 0.015626 0.018217]

# %% [markdown]
# # DQN 2

# %%
report_experiment("dqn_2/1/", n_exp=5, exp_name="dqn 2");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.11655 0.1304  0.13095 0.1319  0.13365] s
# Mean time per simulation step: 0.129 s, std: 0.0062 s
# Total execution time: 12869.000 s for 100000 steps -> 0.129 s per step
#
# Median performance (MSE) in exploitation mode 0.0049
#
# Average MSE in exploitation mode 0.0069 +- 0.0076
# Average exploitation performance of each agent:
# [0.007308 0.007199 0.007308 0.007308 0.005146]

# %%
plot_two_perf_dist("baseline/p_ref=1.2/k=7", "dqn_2/1/")

# %%
report_experiment("dqn_2/2/", n_exp=5, exp_name="dqn 2 - positive reward fct");
# Out:
# Last episode performance: 0.03
# Time per simulation step in each experiment: [0.11025 0.11305 0.1114  0.1108  0.1123 ] s
# Mean time per simulation step: 0.112 s, std: 0.0010 s
# Total execution time: 11156.000 s for 100000 steps -> 0.112 s per step
#
# Median performance (MSE) in exploitation mode 0.0362
#
# Average MSE in exploitation mode 0.0336 +- 0.0097
# Average exploitation performance of each agent:
# [0.044895 0.005049 0.044686 0.044895 0.028623]

# %%
report_experiment("dqn_2/3/", n_exp=5, exp_name="dqn 2 + delta");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.1091  0.1152  0.11765 0.11715 0.1171 ] s
# Mean time per simulation step: 0.115 s, std: 0.0032 s
# Total execution time: 11524.000 s for 100000 steps -> 0.115 s per step
#
# Median performance (MSE) in exploitation mode 0.0049
#
# Average MSE in exploitation mode 0.0069 +- 0.0076
# Average exploitation performance of each agent:
# [0.007308 0.005132 0.007294 0.007308 0.007308]

# %%
plot_two_perf_dist("baseline/p_ref=1.2/k=7", "dqn_2/3/")

# %%
report_experiment("dqn_2/4/", n_exp=5, exp_name="dqn 2 + delta + pos.reward fct.");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.11705 0.1239  0.12555 0.1195  0.1184 ] s
# Mean time per simulation step: 0.121 s, std: 0.0033 s
# Total execution time: 12088.000 s for 100000 steps -> 0.121 s per step
#
# Median performance (MSE) in exploitation mode 0.0043
#
# Average MSE in exploitation mode 0.0102 +- 0.0079
# Average exploitation performance of each agent:
# [0.028623 0.007308 0.005049 0.005049 0.005049]

# %%
report_experiment("dqn_2/5/", n_exp=3, exp_name="dqn 2 + long train");
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.24   0.2396 0.2612] s
# Mean time per simulation step: 0.247 s, std: 0.0101 s
# Total execution time: 14816.000 s for 100000 steps -> 0.148 s per step
#
# Median performance (MSE) in exploitation mode 0.0116
#
# Average MSE in exploitation mode 0.0168 +- 0.0069
# Average exploitation performance of each agent:
# [0.007185 0.031051 0.012305]

# %%
plot_two_perf_dist("baseline/p_ref=1.2/k=7", "dqn_2/5/")

# %%
report_experiment("dqn_2/6/", n_exp=3, exp_name="dqn 2 + delta + long train");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.2696  0.27695 0.27965] s
# Mean time per simulation step: 0.275 s, std: 0.0042 s
# Total execution time: 16524.000 s for 100000 steps -> 0.165 s per step
#
# Median performance (MSE) in exploitation mode 0.0063
#
# Average MSE in exploitation mode 0.0085 +- 0.0073
# Average exploitation performance of each agent:
# [0.013383 0.005012 0.007109]

# %%
report_experiment("dqn_2/7/", n_exp=5, exp_name="dqn 2 + delta + 2048 buffer");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.1181  0.1154  0.11245 0.11355 0.11725] s
# Mean time per simulation step: 0.115 s, std: 0.0021 s
# Total execution time: 11535.000 s for 100000 steps -> 0.115 s per step
#
# Median performance (MSE) in exploitation mode 0.0059
#
# Average MSE in exploitation mode 0.0096 +- 0.0089
# Average exploitation performance of each agent:
# [0.005051 0.005194 0.005143 0.01256  0.019883]

# %%
report_experiment("dqn_2/8/", n_exp=5, exp_name="dqn 2 + delta + 512 buffer, 32 batchs");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.10625 0.1115  0.11465 0.1144  0.11435] s
# Mean time per simulation step: 0.112 s, std: 0.0032 s
# Total execution time: 11223.000 s for 100000 steps -> 0.112 s per step
#
# Median performance (MSE) in exploitation mode 0.0040
#
# Average MSE in exploitation mode 0.0060 +- 0.0081
# Average exploitation performance of each agent:
# [0.005049 0.007221 0.007308 0.005049 0.005134]

# %%
report_experiment("dqn_2/9/", n_exp=5, exp_name="dqn2 +delta +2048buffer, 256 batch");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.10985 0.11005 0.1143  0.1181  0.11695] s
# Mean time per simulation step: 0.114 s, std: 0.0034 s
# Total execution time: 11385.000 s for 100000 steps -> 0.114 s per step
#
# Median performance (MSE) in exploitation mode 0.0076
#
# Average MSE in exploitation mode 0.0130 +- 0.0076
# Average exploitation performance of each agent:
# [0.012148 0.033224 0.007137 0.005052 0.007308]

# %%
report_experiment("dqn_2/10_ReLU/", n_exp=5, exp_name="dqn2 +delta +ReLU not PReLU");
# Out:
# Last episode performance: 0.00
# Time per simulation step in each experiment: [0.11915 0.1199  0.1198  0.1211  0.12115] s
# Mean time per simulation step: 0.120 s, std: 0.0008 s
# Total execution time: 12022.000 s for 100000 steps -> 0.120 s per step
#
# Median performance (MSE) in exploitation mode 0.0040
#
# Average MSE in exploitation mode 0.0060 +- 0.0081
# Average exploitation performance of each agent:
# [0.005049 0.007196 0.005332 0.007125 0.005049]

# %%
plot_perf_dist("baseline/p_ref=1.2/k=7", ["dqn_2/3/", "dqn_2/10_ReLU/"], labels=["PReLU", "ReLU"])

# %%
plot_perf_dist("baseline/p_ref=1.2/k=7", ["dqn_2/8/", "dqn_2/10_ReLU/"], labels=["PReLU", "ReLU"])

# %%
plot_perf_dist("baseline/p_ref=1.2/k=7", ["dqn_2/1/", "dqn_2/3/"], labels=["p_act, p_ref", "p_act, p_ref, delta"])

# %%
report_experiment("dqn_2/11/", n_exp=5, exp_name="dqn2 + delta + 1024 buffer, 32 batch");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.1187  0.12245 0.12245 0.1221  0.12195] s
# Mean time per simulation step: 0.122 s, std: 0.0014 s
# Total execution time: 12153.000 s for 100000 steps -> 0.122 s per step
#
# Median performance (MSE) in exploitation mode 0.0049
#
# Average MSE in exploitation mode 0.0068 +- 0.0075
# Average exploitation performance of each agent:
# [0.005049 0.007156 0.007308 0.007308 0.007308]

# %%
report_experiment("dqn_2/12/", n_exp=5, exp_name="ddqn2 +delta +Target update every 1 000 steps");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.1294  0.12465 0.1235  0.1265  0.12495] s
# Mean time per simulation step: 0.126 s, std: 0.0020 s
# Total execution time: 12580.000 s for 100000 steps -> 0.126 s per step
#
# Median performance (MSE) in exploitation mode 0.0081
#
# Average MSE in exploitation mode 0.0112 +- 0.0071
# Average exploitation performance of each agent:
# [0.005049 0.007308 0.007448 0.019535 0.016503]

# %%
plot_perf_dist("baseline/p_ref=1.2/k=7", ["dqn_2/12/", "dqn_2/11/"], labels=["ddqn", "buffer 1024\nbatch 32"])

# %%
plot_two_perf_dist("baseline/p_ref=1.2/k=7", "dqn_2/12/")

# %%
report_experiment("dqn_2/13/", n_exp=5, exp_name="ddqn2 +delta +Target update every 10 000 steps");
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.11805 0.1225  0.1208  0.12335 0.11965] s
# Mean time per simulation step: 0.121 s, std: 0.0019 s
# Total execution time: 12087.000 s for 100000 steps -> 0.121 s per step
#
# Median performance (MSE) in exploitation mode 0.0109
#
# Average MSE in exploitation mode 0.0151 +- 0.0107
# Average exploitation performance of each agent:
# [0.013066 0.031901 0.013556 0.00725  0.009544]

# %%
report_experiment("dqn_2/14/", n_exp=5, exp_name="ddqn2 +delta +Target update every 10 steps");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.1164  0.12055 0.12755 0.1271  0.1267 ] s
# Mean time per simulation step: 0.124 s, std: 0.0044 s
# Total execution time: 12366.000 s for 100000 steps -> 0.124 s per step
#
# Median performance (MSE) in exploitation mode 0.0030
#
# Average MSE in exploitation mode 0.0055 +- 0.0084
# Average exploitation performance of each agent:
# [0.007308 0.005049 0.005049 0.005049 0.005049]

# %%
report_experiment("dqn_2/15/", n_exp=5, exp_name="ddqn2 +delta +Target update every 1 steps");
# Out:
# Last episode performance: 0.00
# Time per simulation step in each experiment: [0.1331  0.13735 0.1653  0.16095 0.1362 ] s
# Mean time per simulation step: 0.147 s, std: 0.0136 s
# Total execution time: 14658.000 s for 100000 steps -> 0.147 s per step
#
# Median performance (MSE) in exploitation mode 0.0030
#
# Average MSE in exploitation mode 0.0055 +- 0.0084
# Average exploitation performance of each agent:
# [0.005049 0.007308 0.005049 0.005049 0.005049]

# %%
report_experiment("dqn_2/16/", n_exp=5, exp_name="ddqn2 +delta +Target update every 100 steps");
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.1199  0.12475 0.12985 0.1374  0.1374 ] s
# Mean time per simulation step: 0.130 s, std: 0.0069 s
# Total execution time: 12986.000 s for 100000 steps -> 0.130 s per step
#
# Median performance (MSE) in exploitation mode 0.0031
#
# Average MSE in exploitation mode 0.0055 +- 0.0085
# Average exploitation performance of each agent:
# [0.005049 0.007308 0.005049 0.005255 0.005049]

# %%
plot_two_perf_dist("baseline/p_ref=1.2/k=7", "dqn_2/14/")
